# %%
import pandas as pd
import numpy as np
# %matplotlib inline
red_df = pd.read_csv('winequality_red.csv',sep=';')
white_df = pd.read_csv('winequality_white.csv',sep = ';')

# %%
red_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_df.duplicated().sum()
# Out:
# 240

# %%
white_df.duplicated().sum()
# Out:
# 937

# %%
red_df['quality'].nunique()
# Out:
# 6

# %%
white_df['quality'].nunique()
# Out:
# 7

# %%
red_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # We want to merge the two tables,but first we must add a new column with the type of wine (red,white) to be able to differentiate.

# %%
# create color array for red dataframe
color_red = np.repeat('red',1599)

# create color array for white dataframe
color_white = np.repeat('white',4898)

# %%
red_df['color'] = color_red
red_df.rename(columns={'total_sulfur-dioxide':'total_sulfur_dioxide'},inplace = True)
red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
white_df['color'] = color_white
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
#Now we will append them together
# append dataframes
# ignore index to re index the new frame
wine_df = red_df.append(white_df,sort = False,ignore_index=True)

# view dataframe to check for success
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine_df.to_csv('winequality_edited.csv',index=False)

# %% [markdown]
# # Visualizations

# %%
#Visulizations can be found in 'eda_visuals_solutions.ipynb'

# %% [markdown]
# # Group By Examples

# %%
wine_df.mean()
# Out:
# fixed acidity             7.215307
# volatile acidity          0.339666
# citric acid               0.318633
# residual sugar            5.443235
# chlorides                 0.056034
# free sulfur dioxide      30.525319
# total sulfur dioxide    115.744574
# density                   0.994697
# pH                        3.218501
# sulphates                 0.531268
# alcohol                  10.491801
# quality                   5.818378
# dtype: float64

# %%
# This gives us the mean over the whole dataset, but what if I want for example, the mean pH level for all samples with 
# quality rating 7, for this we can use (group by) combined with the mean function to do this.

wine_df.groupby('quality').mean()

# answer is 3.228072
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.853333          0.517000     0.281000        5.140000
# 4             7.288889          0.457963     0.272315        4.153704
# 5             7.326801          0.389614     0.307722        5.804116
# 6             7.177257          0.313863     0.323583        5.549753
# 7             7.128962          0.288800     0.334764        4.731696
# 8             6.835233          0.291010     0.332539        5.382902
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.077033            39.216667            122.033333  0.995744
# 4         0.060056            20.636574            103.432870  0.994833
# 5         0.064666            30.237371            120.839102  0.995849
# 6         0.054157            31.165021            115.410790  0.994558
# ...

# %%
# We can split the dataset with multiple columns to group by using a list in group by clause

wine_df.groupby(['quality','color']).mean()
# Out:
#                fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality color
# 3       red         8.360000          0.884500     0.171000        2.635000
#         white       7.600000          0.333250     0.336000        6.392500
# 4       red         7.779245          0.693962     0.174151        2.694340
#         white       7.129448          0.381227     0.304233        4.628221
# 5       red         8.167254          0.577041     0.243686        2.528855
#         white       6.933974          0.302011     0.337653        7.334969
# 6       red         8.347179          0.497484     0.273824        2.477194
#         white       6.837671          0.260564     0.338025        6.441606
# 7       red         8.872362          0.403920     0.375176        2.720603
#         white       6.734716          0.262767     0.325625        5.186477
# 8       red         8.566667          0.423333     0.391111        2.577778
# ...

# %%
# If we dont want the group by columns to be made as index we can set as_index = False

wine_df.groupby(['quality','color'],as_index = False).mean()
# Out:
#     quality  color  fixed acidity  volatile acidity  citric acid  \
# 0         3    red       8.360000          0.884500     0.171000
# 1         3  white       7.600000          0.333250     0.336000
# 2         4    red       7.779245          0.693962     0.174151
# 3         4  white       7.129448          0.381227     0.304233
# 4         5    red       8.167254          0.577041     0.243686
# 5         5  white       6.933974          0.302011     0.337653
# 6         6    red       8.347179          0.497484     0.273824
# 7         6  white       6.837671          0.260564     0.338025
# 8         7    red       8.872362          0.403920     0.375176
# 9         7  white       6.734716          0.262767     0.325625
# 10        8    red       8.566667          0.423333     0.391111
# 11        8  white       6.657143          0.277400     0.326514
# 12        9  white       7.420000          0.298000     0.386000
#
# ...

# %%
# If we are only interested in certain columns we can do this

wine_df.groupby(['quality','color'],as_index = False)[['pH','chlorides']].mean()
# Out:
#     quality  color        pH  chlorides
# 0         3    red  3.398000   0.122500
# 1         3  white  3.187500   0.054300
# 2         4    red  3.381509   0.090679
# 3         4  white  3.182883   0.050098
# 4         5    red  3.304949   0.092736
# 5         5  white  3.168833   0.051546
# 6         6    red  3.318072   0.084956
# 7         6  white  3.188599   0.045217
# 8         7    red  3.290754   0.076588
# 9         7  white  3.213898   0.038191
# 10        8    red  3.267222   0.068444
# 11        8  white  3.218686   0.038314
# 12        9  white  3.308000   0.027400

# %% [markdown]
# ## Q1: Is a certain type of wine (red or white) associated with higher quality?
# For this question, compare the average quality of red wine with the average quality of white wine with groupby. To do this group by color and then find the mean quality of each group.

# %%
wine_df.groupby(['color'])['quality'].mean()
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %% [markdown]
# ### Conclusion : White wine has a higher quality rating on average.

# %% [markdown]
# ## Q2: What level of acidity (pH value) receives the highest average rating?
# This question is more tricky because unlike color, which has clear categories you can group by (red and white) pH is a quantitative variable without clear categories. However, there is a simple fix to this. You can create a categorical variable from a quantitative variable by creating your own categories. pandas' cut function let's you "cut" data in groups. Using this, create a new column called acidity_levels with these categories:

# %% [markdown]
# Acidity Levels:<br>
# High:Lowest 25% of pH values<br>
# Moderately High: 25% - 50% of pH values<br>
# Medium: 50% - 75% of pH values<br>
# Low: 75% - max pH value<br>

# %%
wine_df['pH'].describe()
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %%
acidity_levels = []
for pH in wine_df['pH']:
    if pH < 3.11:
        acidity_levels.append('High')
    elif pH < 3.21:
        acidity_levels.append('Moderately High')
    elif pH < 3.32:
        acidity_levels.append('Medium')
    else:
        acidity_levels.append('Low')

# %%
wine_df['acidity_level'] = acidity_levels
wine_df[['pH','acidity_level']]
# Out:
#         pH    acidity_level
# 0     3.51              Low
# 1     3.20  Moderately High
# 2     3.26           Medium
# 3     3.16  Moderately High
# 4     3.51              Low
# ...    ...              ...
# 6492  3.27           Medium
# 6493  3.15  Moderately High
# 6494  2.99             High
# 6495  3.34              Low
# 6496  3.26           Medium
#
# [6497 rows x 2 columns]

# %% [markdown]
# ### We will now remove the column and add it again using another method called bins

# %%
del wine_df['acidity_level']
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
bin_edges = [2.72,3.11,3.21,3.32,4.01]
bins = ['High','Moderately High','Medium','Low']

# %%
wine_df['acidity_level'] = pd.cut(wine_df['pH'],bin_edges,labels=bins)
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color    acidity_level
# 0      9.4        5   red              Low
# ...

# %%
# Find the mean quality of each acidity level with groupby
wine_df.groupby('acidity_level',as_index = False).mean()
# Out:
#      acidity_level  fixed acidity  volatile acidity  citric acid  \
# 0             High       7.543914          0.294683     0.370792
# 1  Moderately High       7.365064          0.318551     0.340548
# 2           Medium       7.143566          0.346751     0.313585
# 3              Low       6.769949          0.403815     0.243901
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0        7.088876   0.055131            33.179965            129.897496
# 1        5.931984   0.054666            33.229154            126.815886
# 2        4.721159   0.055715            28.983995            111.182138
# 3        3.848983   0.058777            26.327510             93.244917
#
#     density        pH  sulphates    alcohol   quality
# 0  0.994708  3.029062   0.503937  10.330208  5.783343
# 1  0.994697  3.164833   0.509300  10.391073  5.784540
# 2  0.994476  3.267010   0.541287  10.610369  5.850832
# 3  0.994899  3.433348   0.574136  10.656057  5.859593

# %%
# Save changes for the next section
wine_df.to_csv('winequality_acidity_level_index.csv', index=False)

# %% [markdown]
# # Drawing conclusions

# %% [markdown]
# ## Q1: Do wines with higher alcoholic content receive better ratings?
# To answer this question, use query to create two groups of wine samples:
#
# Low alcohol (samples with an alcohol content less than the median)<br>
# High alcohol (samples with an alcohol content greater than or equal to the median)<br>
# Then, find the mean quality rating of each group.

# %%
# get the median amount of alcohol content
wine_df['alcohol'].median()
# Out:
# 10.3

# %%
# select samples with alcohol content less than the median
low_alcohol = wine_df[wine_df['alcohol'] < 10.3]

# select samples with alcohol content greater than or equal to the median
high_alcohol = wine_df[wine_df['alcohol'] >= 10.3]

# ensure these queries included each sample exactly once
num_samples = wine_df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count()
# Out:
# True

# %%
# get mean quality rating for the low alcohol and high alcohol groups
print(low_alcohol['quality'].mean())
print(high_alcohol['quality'].mean())
# Out:
# 5.475920679886686
# 6.146084337349397

# %% [markdown]
# ### Conclusion : Wines with higher alcohol content get higher ratings

# %%
# get the median amount of residual sugar
wine_df['residual sugar'].median()
# Out:
# 3.0

# %%
# select samples with residual sugar less than the median
low_sugar = wine_df[wine_df['residual sugar'] < 3.0]

# select samples with residual sugar greater than or equal to the median
high_sugar = wine_df[wine_df['residual sugar'] >= 3.0]

# ensure these queries included each sample exactly once
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low sugar and high sugar groups
print(low_sugar['quality'].mean())
print(high_sugar['quality'].mean())
# Out:
# 5.808800743724822
# 5.82782874617737

# %% [markdown]
# ### Conclusion : Wines with higher sugar content get higher ratings

# %% [markdown]
# # Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
colors = ['red','white']
wine_df.groupby('color')['quality'].mean()
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
color_means = wine_df.groupby('color')['quality'].mean()
color_means.plot(kind='bar', title = 'Average rating by color',color=colors,alpha = 1).set_facecolor('xkcd:light grey')

plt.xlabel('Color',fontsize = 18)
plt.ylabel('Quality',fontsize = 18)
# Out:
# Text(0, 0.5, 'Quality')

# %%
counts = wine_df.groupby(['quality','color']).count()['pH']
counts.plot(kind='bar',title='Counts by wine quality and color',color=colors,alpha=1).set_facecolor('xkcd:light grey')
plt.xlabel('Quality and Color',fontsize = 18)
plt.ylabel('Count',fontsize = 18)
# Out:
# Text(0, 0.5, 'Count')

# %%
#Lets use porportions instead of count to make a fair comparison

totals = wine_df.groupby('color').count()['pH']
proportions = counts/totals

# %%
proportions.plot(kind='bar',title='Proportion by wine quality and color',color=colors,alpha=1).set_facecolor('xkcd:light grey')
plt.xlabel('Quality and Color',fontsize = 18)
plt.ylabel('Count',fontsize = 18)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Creating a Bar Chart Using Matplotlib

# %% [markdown]
# There are two required arguments in pyplot's bar function: the x-coordinates of the bars, and the heights of the bars.

# %%
plt.bar([1,2,3],[224,620,425]);

# %%
plt.bar([1,2,3],[224,620,425]);
plt.xticks([1,2,3],['a','b','c']);

# %%
#another method to put labels
plt.bar([1,2,3],[224,620,425],tick_label=['a','b','c']);

# %%
plt.bar([1,2,3],[224,620,425],tick_label=['a','b','c']);
plt.title('Title')
plt.xlabel('X label')
plt.ylabel('Y label')
# Out:
# Text(0, 0.5, 'Y label')

# %%
#Continuing from line 70

mean_quality_low = low_alcohol['quality'].mean()
mean_quality_high = high_alcohol['quality'].mean()

# %%
positions = [1,2]
heights = [mean_quality_low,mean_quality_high]
labels = ['Low Alcohol','High Alcohol']
plt.bar(positions,heights,tick_label=labels)
plt.title('Average quality rating by alcohol content')
plt.xlabel('Alcohol content')
plt.ylabel('Average quality rating')
# Out:
# Text(0, 0.5, 'Average quality rating')

# %%
mean_low_sugar = low_sugar['quality'].mean()
mean_high_sugar = high_sugar['quality'].mean()

# %%
positions = [1,2]
heights = [mean_low_sugar,mean_high_sugar]
labels = ['Low sugar','High sugar']
plt.bar(positions,heights,tick_label=labels)
plt.title('Average quality rating by sugar content')
plt.xlabel('Sugar content')
plt.ylabel('Average quality rating');
